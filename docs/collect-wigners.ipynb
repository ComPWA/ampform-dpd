# %% [markdown]
# # Collect angular distribution symbols
#
# ```{autolink-concat}
# ```

# %%
import logging

import qrules
import sympy as sp
from IPython.display import Latex, Markdown

from ampform_dpd import DalitzPlotDecompositionBuilder, DefinedExpression
from ampform_dpd.adapter.qrules import (
    load_particles,
    normalize_state_ids,
    to_three_body_decay,
)
from ampform_dpd.decay import ThreeBodyDecayChain
from ampform_dpd.dynamics.builder import get_mandelstam_s
from ampform_dpd.io import aslatex, cached, simplify_latex_rendering

simplify_latex_rendering()
logging.getLogger("qrules.transition").setLevel(logging.ERROR)

# %% [markdown]
# ## Decay definition

# %%
PARTICLES = load_particles()
for name in [
    "K*(1410)~0",
    "K(2)*(1430)~0",
    "K*(1680)~0",
    "Delta(1620)++",
    "Delta(1900)++",
    "Delta(1910)++",
    "Delta(1920)++",
    "Lambda(1800)",
    "Lambda(1810)",
    "Lambda(1890)",
]:
    PARTICLES.remove(PARTICLES[name])
STM = qrules.StateTransitionManager(
    initial_state=["Lambda(c)+"],
    final_state=["p", "K-", "pi+"],
    mass_conservation_factor=3,
    allowed_intermediate_particles=["K", "Delta", "Lambda"],
    particle_db=PARTICLES,
    max_angular_momentum=2,
    formalism="canonical-helicity",
)
STM.set_allowed_interaction_types([qrules.InteractionType.STRONG], node_id=1)
problem_sets = STM.create_problem_sets()
REACTION = STM.find_solutions(problem_sets)
REACTION = normalize_state_ids(REACTION)
src = qrules.io.asmermaid(REACTION, collapse_graphs=True, markdown=True)
Markdown(src)

# %%
DECAY = to_three_body_decay(REACTION.transitions, min_ls=True)
Latex(aslatex(DECAY, with_jp=True))

# %% [markdown]
# ## Dynamics as a symbol
#
# Instead of a lineshape, the dynamics builder below returns a plain `~sympy.core.symbol.Symbol` that carries the spin of the resonance and the $LS$-couplings of the production and decay node. The symbol acts as a placeholder that marks which part of the intensity expression belongs to which decay chain.

# %%
def formulate_dynamics_symbol(decay_chain: ThreeBodyDecayChain) -> DefinedExpression:
    s = get_mandelstam_s(decay_chain.decay_node)
    assert decay_chain.incoming_ls is not None
    assert decay_chain.outgoing_ls is not None
    l_prod = sp.Rational(decay_chain.incoming_ls.L)
    s_prod = sp.Rational(decay_chain.incoming_ls.S)
    l_dec = sp.Rational(decay_chain.outgoing_ls.L)
    s_dec = sp.Rational(decay_chain.outgoing_ls.S)
    spin = decay_chain.resonance.spin
    symbol = sp.Symbol(
        Rf"X_{{{spin}}}^{{{l_prod},{s_prod};{l_dec},{s_dec}}}"
        Rf"\left({sp.latex(s)}\right)"
    )
    return DefinedExpression(symbol)

# %% [markdown]
# ## Model formulation

# %%
model_builder = DalitzPlotDecompositionBuilder(DECAY, min_ls=(False, True))
for chain in model_builder.decay.chains:
    model_builder.dynamics_choices.register_builder(chain, formulate_dynamics_symbol)
model = model_builder.formulate(reference_subsystem=1)
model.intensity

# %% [markdown]
# ## Angular distribution per dynamics symbol
#
# With all couplings set to one, each dynamics symbol is multiplied by the angular part of the decay chain it represents. Setting one symbol to one and all others to zero therefore isolates that angular distribution.

# %%
couplings_to_one = {s: 1 for s in model.parameter_defaults if "mathcal" in str(s)}
full_expression = cached.xreplace(cached.unfold(model), couplings_to_one)
dynamic_symbols = sorted(
    (s for s in full_expression.free_symbols if str(s).startswith("X")),
    key=lambda s: (str(s)[-10:], str(s)),
)

# %%
src = R"""
\begin{eqnarray}
"""
for x in dynamic_symbols:
    filter_substitutions = {s: 1 if s == x else 0 for s in dynamic_symbols}
    factor = cached.simplify(cached.xreplace(full_expression, filter_substitutions))
    src += Rf"{sp.latex(x)} &:& {sp.latex(factor)} \\" "\n"
src += R"\end{eqnarray}"
Latex(src)
